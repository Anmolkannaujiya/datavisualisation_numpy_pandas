# %% [markdown]
# ### axis 0 and 1 for column and row

# %%
import numpy as np

# %%
arr = np.random.randint(4,18,9).reshape(3,3)
arr
# Out:
# array([[14,  7,  9],
#        [17,  9, 17],
#        [ 4,  6,  8]])

# %%
arr.sum()
# Out:
# 91

# %%
np.sum(arr)
#two ways can be done
# Out:
# 91

# %%
np.min(arr,axis=1)
# Out:
# array([7, 9, 4])

# %%
np.argmin(arr, axis=0)
# Out:
# array([2, 2, 2], dtype=int64)

# %%
np.sum(arr,axis=1)
# Out:
# array([30, 43, 18])

# %% [markdown]
# #### cummulative sum

# %%
np.cumsum(arr)
# Out:
# array([14, 21, 30, 47, 56, 73, 77, 83, 91])

# %%
np.cumsum(arr, axis=0)
# Out:
# array([[14,  7,  9],
#        [31, 16, 26],
#        [35, 22, 34]])

# %%
np.cumsum(arr,axis=1)
# Out:
# array([[14, 21, 30],
#        [17, 26, 43],
#        [ 4, 10, 18]])
