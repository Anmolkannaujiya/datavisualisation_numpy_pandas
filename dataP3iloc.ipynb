# %% [markdown]
# #### using traditional indexing for row slection

# %%
import pandas as pd

# %%
movies_data = pd.read_csv(r"C:\Users\anmol\OneDrive\Desktop\RESOURCES\Cipherschools\cipherschools python visualization\tmdb_5000_movies.csv")

# %%
movies_data.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies_data[2:5]
# Out:
#       budget                                             genres  \
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                       homepage      id  \
# 2  http://www.sonypictures.com/movies/spectre/  206647
# 3           http://www.thedarkknightrises.com/   49026
# 4         http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
#
#           original_title                                           overview  \
# 2                Spectre  A cryptic message from Bond’s past sends him o...
# ...

# %%
data = movies_data[2:5]

# %%
data[["original_title","runtime"]]
# Out:
#           original_title  runtime
# 2                Spectre    148.0
# 3  The Dark Knight Rises    165.0
# 4            John Carter    132.0

# %% [markdown]
# ## now using iloc to do slicing and selection

# %%
print(movies_data.iloc[0])
typep =type(movies_data.iloc[0])
print("type of data is:",typep)
# Out:
# budget                                                          237000000
# genres                  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# homepage                                      http://www.avatarmovie.com/
# id                                                                  19995
# keywords                [{"id": 1463, "name": "culture clash"}, {"id":...
# original_language                                                      en
# original_title                                                     Avatar
# overview                In the 22nd century, a paraplegic Marine is di...
# popularity                                                     150.437577
# production_companies    [{"name": "Ingenious Film Partners", "id": 289...
# production_countries    [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                   2009-12-10
# revenue                                                        2787965087
# ...

# %%
movies_data.iloc[3:6]
#range slicing
# Out:
#       budget                                             genres  \
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5  258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
#
#                                           homepage     id  \
# 3               http://www.thedarkknightrises.com/  49026
# 4             http://movies.disney.com/john-carter  49529
# 5  http://www.sonypictures.com/movies/spider-man3/    559
#
#                                             keywords original_language  \
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4  [{"id": 818, "name": "based on novel"}, {"id":...                en
# 5  [{"id": 851, "name": "dual identity"}, {"id": ...                en
#
#           original_title                                           overview  \
# 3  The Dark Knight Rises  Following the death of District Attorney Harve...
# ...

# %%
movies_data.iloc[[0,11,24]]
#inputing index for individual selection
# Out:
#        budget                                             genres  \
# 0   237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 11  200000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 24  207000000  [{"id": 12, "name": "Adventure"}, {"id": 18, "...
#
#                                              homepage     id  \
# 0                         http://www.avatarmovie.com/  19995
# 11  http://www.mgm.com/view/movie/234/Quantum-of-S...  10764
# 24                                                NaN    254
#
#                                              keywords original_language  \
# 0   [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 11  [{"id": 627, "name": "killing"}, {"id": 1568, ...                en
# 24  [{"id": 774, "name": "film business"}, {"id": ...                en
#
#        original_title                                           overview  \
# 0              Avatar  In the 22nd century, a paraplegic Marine is di...
# ...

# %% [markdown]
# ### Both row and column can be selected
# they are separated by a comma, and any way they can be called of the the three way mentioned above

# %%
movies_data.iloc[[0,10],[6,2]]
# Out:
#       original_title                     homepage
# 0             Avatar  http://www.avatarmovie.com/
# 10  Superman Returns      http://www.superman.com

# %% [markdown]
# #movies_data.iloc[[0:3],[3,5]]
# ##### will give error since we should not use list inside it if it is not list eg: [[1,4,10]] is correct but [[0:4],[0:5]]
# ##### is incorrect the correct would be [o:4,0:6]

# %%
#movies_data.iloc[[0:3],[0:3]]
#wrong

# %%
movies_data.iloc[0,6]
# Out:
# 'Avatar'

# %%
movies_data.iloc[0:4,1:6]
# Out:
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
#
#                                             keywords original_language
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3  [{"id": 849, "name": "dc comics"}, {"id": 853,...                en

# %%
movies_data.iloc[[10,34,67],0:8]
# Out:
#        budget                                             genres  \
# 10  270000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 34  200000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 67  175000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
#
#                             homepage     id  \
# 10           http://www.superman.com   1452
# 34                               NaN  62211
# 67  http://www.monstersvsaliens.com/  15512
#
#                                              keywords original_language  \
# 10  [{"id": 83, "name": "saving the world"}, {"id"...                en
# 34  [{"id": 1299, "name": "monster"}, {"id": 5984,...                en
# 67  [{"id": 9951, "name": "alien"}, {"id": 10891, ...                en
#
#          original_title                                           overview
# 10     Superman Returns  Superman returns to discover his 5-year absenc...
# 34  Monsters University  A look at the relationship between Mike and Su...
# ...
