# %% [markdown]
# ### moving further to create series after learning series|

# %%
import pandas as pd

# %%
movies_data = pd.read_csv(r"C:\Users\anmol\OneDrive\Desktop\RESOURCES\Cipherschools\cipherschools python visualization\tmdb_5000_movies.csv")

# %%
movies_data.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
type(movies_data['runtime'])
# Out:
# pandas.core.series.Series

# %%
anime = ['one piece','one punch','my hero academia','doraemon','pokemin','attack on titans','dangers in my heart','naruto','bleach']

# %%
anime
# Out:
# ['one piece',
#  'one punch',
#  'my hero academia',
#  'doraemon',
#  'pokemin',
#  'attack on titans',
#  'dangers in my heart',
#  'naruto',
#  'bleach']

# %%
anime_series = pd.Series(anime)

# %%
anime_series
# Out:
# 0              one piece
# 1              one punch
# 2       my hero academia
# 3               doraemon
# 4                pokemin
# 5       attack on titans
# 6    dangers in my heart
# 7                 naruto
# 8                 bleach
# dtype: object

# %%
#we will create a sereis where we will pass anime name as the index of the series we are gonna create that will contain the genre of the anime
genre = ['shonen','adventure','sport','shonen','isekai','shonen','action','kodomon','shonen']

# %%
anime_series = pd.Series(anime,name='my anime list')

# %%
anime_series
# Out:
# 0              one piece
# 1              one punch
# 2       my hero academia
# 3               doraemon
# 4                pokemin
# 5       attack on titans
# 6    dangers in my heart
# 7                 naruto
# 8                 bleach
# Name: my anime list, dtype: object

# %%
genre_series = pd.Series(genre, index=anime, name='full list along with genre')

# %%
genre_series
# Out:
# one piece                 shonen
# one punch              adventure
# my hero academia           sport
# doraemon                  shonen
# pokemin                   isekai
# attack on titans          shonen
# dangers in my heart       action
# naruto                   kodomon
# bleach                    shonen
# Name: full list along with genre, dtype: object

# %%
#trying to pass another series instead of the list as the index
genre_series = pd.Series(genre, index=anime_series, name='anime list')
genre_series
# Out:
# my anime list
# one piece                 shonen
# one punch              adventure
# my hero academia           sport
# doraemon                  shonen
# pokemin                   isekai
# attack on titans          shonen
# dangers in my heart       action
# naruto                   kodomon
# bleach                    shonen
# Name: anime list, dtype: object

# %% [markdown]
# ### similarly we can pass np array as well instead of the list or the panda series, or an data like the tuples etc.

# %%
#eg trying with array

# %%
import numpy as np

# %%
anime2 = np.array( ['one piece','one punch','my hero academia','doraemon','pokemin','attack on titans','dangers in my heart','naruto','bleach'])

# %%
genre2 = np.array(['shonen','adventure','sport','shonen','isekai','shonen','action','kodomon','shonen'])

# %%
genre_series2 = pd.Series(genre2, index=anime2, name='alternate')
genre_series2
# Out:
# one piece                 shonen
# one punch              adventure
# my hero academia           sport
# doraemon                  shonen
# pokemin                   isekai
# attack on titans          shonen
# dangers in my heart       action
# naruto                   kodomon
# bleach                    shonen
# Name: alternate, dtype: object

# %% [markdown]
# ### working with dictionary

# %%
dic = {
    'one piece' : 'shonen',
    'one punch': 'adventure',
    'my hero academia': 'shonen',
    'doraemon': 'isekai',
    'pokemin': 'sport',
    'attack on titans': 'action',
    'dangers in my heart':'shonen' ,
    'naruto': 'sport',
    'bleach': 'shonen'
}

# %%
pd.Series(dic,name='anime_genre')
# Out:
# one piece                 shonen
# one punch              adventure
# my hero academia          shonen
# doraemon                  isekai
# pokemin                    sport
# attack on titans          action
# dangers in my heart       shonen
# naruto                     sport
# bleach                    shonen
# Name: anime_genre, dtype: object

# %% [markdown]
# ### during reading csv we can convert the dataframe into series or can select only the desired columns

# %%
#here we are trying to read just few colmns 
data = pd.read_csv(r"C:\Users\anmol\OneDrive\Desktop\RESOURCES\Cipherschools\cipherschools python visualization\tmdb_5000_movies.csv", usecols=['runtime','genres'])

# %%
data
# Out:
#                                                  genres  runtime
# 0     [{"id": 28, "name": "Action"}, {"id": 12, "nam...    162.0
# 1     [{"id": 12, "name": "Adventure"}, {"id": 14, "...    169.0
# 2     [{"id": 28, "name": "Action"}, {"id": 12, "nam...    148.0
# 3     [{"id": 28, "name": "Action"}, {"id": 80, "nam...    165.0
# 4     [{"id": 28, "name": "Action"}, {"id": 12, "nam...    132.0
# ...                                                 ...      ...
# 4798  [{"id": 28, "name": "Action"}, {"id": 80, "nam...     81.0
# 4799  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...     85.0
# 4800  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...    120.0
# 4801                                                 []     98.0
# 4802                [{"id": 99, "name": "Documentary"}]     90.0
#
# [4803 rows x 2 columns]

# %%
#can also read one colmn but it will still be in dataframe until we convert it into series

# %%
#data =  pd.read_csv(r"C:\Users\anmol\OneDrive\Desktop\RESOURCES\Cipherschools\cipherschools python visualization\tmdb_5000_movies.csv", 
                    #usecols=['runtime'], squeeze = True)
#error since squeeze no longer fuctions

# %%
data =  pd.read_csv(r"C:\Users\anmol\OneDrive\Desktop\RESOURCES\Cipherschools\cipherschools python visualization\tmdb_5000_movies.csv", 
                    usecols=['runtime'])['runtime']
#newer way to convert into series form dataframe

# %%
data
# Out:
# 0       162.0
# 1       169.0
# 2       148.0
# 3       165.0
# 4       132.0
#         ...
# 4798     81.0
# 4799     85.0
# 4800    120.0
# 4801     98.0
# 4802     90.0
# Name: runtime, Length: 4803, dtype: float64

# %%
type(data)
# Out:
# pandas.core.series.Series
