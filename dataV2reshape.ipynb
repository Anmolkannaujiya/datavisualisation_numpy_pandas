# %%
import numpy as np

# %%
arr = np.random.randint(1,100,20)

# %%
arr
# Out:
# array([ 6, 23, 81, 87, 62,  8, 97, 30, 56, 94, 14, 64, 63, 36, 66,  3,  5,
#        73, 98, 59])

# %%
arr.reshape(2,10)
# Out:
# array([[ 6, 23, 81, 87, 62,  8, 97, 30, 56, 94],
#        [14, 64, 63, 36, 66,  3,  5, 73, 98, 59]])

# %%
arr.reshape(5,4)
# Out:
# array([[ 6, 23, 81, 87],
#        [62,  8, 97, 30],
#        [56, 94, 14, 64],
#        [63, 36, 66,  3],
#        [ 5, 73, 98, 59]])

# %%
arr
#arr value didn't changed since we did not reassign it and just printed the operation
# Out:
# array([ 6, 23, 81, 87, 62,  8, 97, 30, 56, 94, 14, 64, 63, 36, 66,  3,  5,
#        73, 98, 59])

# %%
arr = arr.reshape(2,2,5)

# %%
arr
# Out:
# array([[[ 6, 23, 81, 87, 62],
#         [ 8, 97, 30, 56, 94]],
#
#        [[14, 64, 63, 36, 66],
#         [ 3,  5, 73, 98, 59]]])

# %%
arr = arr.reshape(20)
arr
# Out:
# array([ 6, 23, 81, 87, 62,  8, 97, 30, 56, 94, 14, 64, 63, 36, 66,  3,  5,
#        73, 98, 59])

# %%
arr = arr.reshape(2,2,5)
#arr = arr.reshape(15)
#reshape(15) will not work since it arr of 20 cannot bemade 15

# %%
arr
# Out:
# array([[[ 6, 23, 81, 87, 62],
#         [ 8, 97, 30, 56, 94]],
#
#        [[14, 64, 63, 36, 66],
#         [ 3,  5, 73, 98, 59]]])

# %% [markdown]
# ### using the -1 in reshape

# %%
arr.reshape(-1)
# Out:
# array([ 6, 23, 81, 87, 62,  8, 97, 30, 56, 94, 14, 64, 63, 36, 66,  3,  5,
#        73, 98, 59])

# %%
arr.reshape(-1,5)
# Out:
# array([[ 6, 23, 81, 87, 62],
#        [ 8, 97, 30, 56, 94],
#        [14, 64, 63, 36, 66],
#        [ 3,  5, 73, 98, 59]])

# %%
arr.reshape(2,-1)
# Out:
# array([[ 6, 23, 81, 87, 62,  8, 97, 30, 56, 94],
#        [14, 64, 63, 36, 66,  3,  5, 73, 98, 59]])
