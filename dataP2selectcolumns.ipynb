# %%
import pandas as pd

# %%
data = pd.read_csv("tmdb_5000_movies.csv")
print(data)
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
print(data['budget'])
print("1st 30 budjget\n")
data['budget'].head(30) #will display 1st 30 budget, .tail(30) last 30
# Out:
# 0       237000000
# 1       300000000
# 2       245000000
# 3       250000000
# 4       260000000
#           ...
# 4798       220000
# 4799         9000
# 4800            0
# 4801            0
# 4802            0
# Name: budget, Length: 4803, dtype: int64
# 1st 30 budjget
# 0     237000000
# 1     300000000
# 2     245000000
# 3     250000000
# 4     260000000
# 5     258000000
# 6     260000000
# 7     280000000
# 8     250000000
# 9     250000000
# 10    270000000
# 11    200000000
# 12    200000000
# 13    255000000
# 14    225000000
# 15    225000000
# 16    220000000
# 17    380000000
# 18    225000000
# 19    250000000
# 20    215000000
# 21    200000000
# 22    250000000
# 23    180000000
# 24    207000000
# 25    200000000
# 26    250000000
# 27    209000000
# 28    150000000
# 29    200000000
# Name: budget, dtype: int64

# %%
data[['budget','original_title']]
#when more than one column name then use list of them mean double bracket [[]]
# Out:
#          budget                            original_title
# 0     237000000                                    Avatar
# 1     300000000  Pirates of the Caribbean: At World's End
# 2     245000000                                   Spectre
# 3     250000000                     The Dark Knight Rises
# 4     260000000                               John Carter
# ...         ...                                       ...
# 4798     220000                               El Mariachi
# 4799       9000                                 Newlyweds
# 4800          0                 Signed, Sealed, Delivered
# 4801          0                          Shanghai Calling
# 4802          0                         My Date with Drew
#
# [4803 rows x 2 columns]
