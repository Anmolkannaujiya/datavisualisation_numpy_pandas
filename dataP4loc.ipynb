# %% [markdown]
# ### we will loc to call values using names of the columns

# %%
import pandas as pd

# %%
movies_data = pd.read_csv(r"C:\Users\anmol\OneDrive\Desktop\RESOURCES\Cipherschools\cipherschools python visualization\tmdb_5000_movies.csv")
#note: the column can be set index during read_csv itself 
#eg:- df = pd.read_csv(r"link", index_col = "original_title")
movies_data.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies_data.loc[9]
# Out:
# budget                                                          250000000
# genres                  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# homepage                     http://www.batmanvsupermandawnofjustice.com/
# id                                                                 209112
# keywords                [{"id": 849, "name": "dc comics"}, {"id": 7002...
# original_language                                                      en
# original_title                         Batman v Superman: Dawn of Justice
# overview                Fearing the actions of a god-like Super Hero l...
# popularity                                                     155.790452
# production_companies    [{"name": "DC Comics", "id": 429}, {"name": "A...
# production_countries    [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                   2016-03-23
# revenue                                                         873260194
# ...

# %%
movies_data.loc[0:4]
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies_data = movies_data.set_index('original_title')
#note: the column can be set index during read_csv itself 
#eg:- df = pd.read_csv(r"link", index_col = "original_title")

# %%
movies_data
# Out:
#                                              budget  \
# original_title
# Avatar                                    237000000
# Pirates of the Caribbean: At World's End  300000000
# Spectre                                   245000000
# The Dark Knight Rises                     250000000
# John Carter                               260000000
# ...                                             ...
# El Mariachi                                  220000
# Newlyweds                                      9000
# Signed, Sealed, Delivered                         0
# Shanghai Calling                                  0
# My Date with Drew                                 0
#
#                                                                                      genres  \
# original_title
# Avatar                                    [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# Pirates of the Caribbean: At World's End  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# ...

# %%
movies_data.loc['Avatar']
#using loc usiing the title as index to print the whole row
# Out:
# budget                                                          237000000
# genres                  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# homepage                                      http://www.avatarmovie.com/
# id                                                                  19995
# keywords                [{"id": 1463, "name": "culture clash"}, {"id":...
# original_language                                                      en
# overview                In the 22nd century, a paraplegic Marine is di...
# popularity                                                     150.437577
# production_companies    [{"name": "Ingenious Film Partners", "id": 289...
# production_countries    [{"iso_3166_1": "US", "name": "United States o...
# release_date                                                   2009-12-10
# revenue                                                        2787965087
# runtime                                                             162.0
# ...

# %%
#using list to pass multiple names
movies_data.loc[['Avatar','John Carter','Batman v Superman: Dawn of Justice']]
# Out:
#                                        budget  \
# original_title
# Avatar                              237000000
# John Carter                         260000000
# Batman v Superman: Dawn of Justice  250000000
#
#                                                                                genres  \
# original_title
# Avatar                              [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# John Carter                         [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# Batman v Superman: Dawn of Justice  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                                                         homepage  \
# original_title
# Avatar                                               http://www.avatarmovie.com/
# John Carter                                 http://movies.disney.com/john-carter
# Batman v Superman: Dawn of Justice  http://www.batmanvsupermandawnofjustice.com/
#
#                                         id  \
# ...

# %%
movies_data.loc[['Avatar','John Carter','Batman v Superman: Dawn of Justice'], ['id','homepage']]
#selecting both rows and colmns
# Out:
#                                         id  \
# original_title
# Avatar                               19995
# John Carter                          49529
# Batman v Superman: Dawn of Justice  209112
#
#                                                                         homepage
# original_title
# Avatar                                               http://www.avatarmovie.com/
# John Carter                                 http://movies.disney.com/john-carter
# Batman v Superman: Dawn of Justice  http://www.batmanvsupermandawnofjustice.com/

# %%
#movies_data.loc[['Avatar','John Carter'],0:4]   #wrong : column should be label

# %%
#finding the range using labels
movies_data.loc['Avatar':'Batman v Superman: Dawn of Justice','homepage':'popularity']
# Out:
#                                                                                    homepage  \
# original_title
# Avatar                                                          http://www.avatarmovie.com/
# Pirates of the Caribbean: At World's End       http://disney.go.com/disneypictures/pirates/
# Spectre                                         http://www.sonypictures.com/movies/spectre/
# The Dark Knight Rises                                    http://www.thedarkknightrises.com/
# John Carter                                            http://movies.disney.com/john-carter
# Spider-Man 3                                http://www.sonypictures.com/movies/spider-man3/
# Tangled                                        http://disney.go.com/disneypictures/tangled/
# Avengers: Age of Ultron                   http://marvel.com/movies/movie/193/avengers_ag...
# Harry Potter and the Half-Blood Prince    http://harrypotter.warnerbros.com/harrypottera...
# ...

# %% [markdown]
# ## can use numerical indexing for columns as well using some bypassing methods

# %%
#Method 1 :
movies_data.loc[['Avatar','John Carter'],movies_data.columns[2:5]]
# Out:
#                                             homepage     id  \
# original_title
# Avatar                   http://www.avatarmovie.com/  19995
# John Carter     http://movies.disney.com/john-carter  49529
#
#                                                          keywords
# original_title
# Avatar          [{"id": 1463, "name": "culture clash"}, {"id":...
# John Carter     [{"id": 818, "name": "based on novel"}, {"id":...

# %%
#Method 2: nesting loc inside iloc, using get_loc to get the name then passing the index of rows, and ineterger range of colmn

# %%
#Method 3: finding index of the rows and using iloc instead

#rows = movies_data.index.get_indexer(['Avatar','John Carter'])  
#movies_data.iloc[rows,1:4]
#we get error beacuse there is duplicate in the index name and indexing only happens with unique values

#movies_data.index.is_unique  #true or false for duplicates
movies_data.index[movies_data.index.duplicated(keep=False)]   #will tell the names of the duplicates
# Out:
# Index(['Batman', 'Out of the Blue', 'Out of the Blue', 'Batman'], dtype='object', name='original_title')
