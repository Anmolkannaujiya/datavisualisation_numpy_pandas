# %% [markdown]
# #### Seed for same random numbers

# %%
import numpy as np

# %%
np.random.seed(53)
arr = np.random.randint(1,101,10).reshape(2,-1)
arr
# Out:
# array([[26, 30, 38, 62, 23],
#        [64, 49, 89, 59, 13]])

# %%
arr.size
# Out:
# 10
