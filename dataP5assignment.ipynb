# %% [markdown]
# ### assignment analysing world happiness index

# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\anmol\OneDrive\Desktop\RESOURCES\Cipherschools\cipherschools python visualization\2015.csv")

# %%
data.head(5)
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
data.tail(5)
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=158, step=1)

# %%
data.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
data.iloc[5:11]
# Out:
#         Country                           Region  Happiness Rank  \
# 5       Finland                   Western Europe               6
# 6   Netherlands                   Western Europe               7
# 7        Sweden                   Western Europe               8
# 8   New Zealand        Australia and New Zealand               9
# 9     Australia        Australia and New Zealand              10
# 10       Israel  Middle East and Northern Africa              11
#
#     Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 5             7.406         0.03140                   1.29025  1.31826
# 6             7.378         0.02799                   1.32944  1.28017
# 7             7.364         0.03157                   1.33171  1.28907
# 8             7.286         0.03371                   1.25018  1.31967
# 9             7.284         0.04083                   1.33358  1.30923
# 10            7.278         0.03470                   1.22857  1.22393
#
# ...

# %%
#selecting single country, when index is not set for country name
data[data['Country']=='India']
# Out:
#     Country         Region  Happiness Rank  Happiness Score  Standard Error  \
# 116   India  Southern Asia             117            4.565         0.02043
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 116                   0.64499  0.38174                   0.51529  0.39786
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 116                        0.08492     0.26475            2.27513

# %%
data[data['Country'].isin(['India', 'Japan', 'China'])]
#selecxting multiple country whenn country is not index
# Out:
#     Country         Region  Happiness Rank  Happiness Score  Standard Error  \
# 45    Japan   Eastern Asia              46            5.987         0.03581
# 83    China   Eastern Asia              84            5.140         0.02424
# 116   India  Southern Asia             117            4.565         0.02043
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 45                    1.27074  1.25712                   0.99111  0.49615
# 83                    0.89012  0.94675                   0.81658  0.51697
# 116                   0.64499  0.38174                   0.51529  0.39786
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 45                         0.18060     0.10705            1.68435
# 83                         0.02781     0.08185            1.86040
# 116                        0.08492     0.26475            2.27513

# %%
data = data.set_index("Country")
#ssetting country index

# %%
data
# Out:
#                                       Region  Happiness Rank  Happiness Score  \
# Country
# Switzerland                   Western Europe               1            7.587
# Iceland                       Western Europe               2            7.561
# Denmark                       Western Europe               3            7.527
# Norway                        Western Europe               4            7.522
# Canada                         North America               5            7.427
# ...                                      ...             ...              ...
# Rwanda                    Sub-Saharan Africa             154            3.465
# Benin                     Sub-Saharan Africa             155            3.340
# Syria        Middle East and Northern Africa             156            3.006
# Burundi                   Sub-Saharan Africa             157            2.905
# Togo                      Sub-Saharan Africa             158            2.839
#
# ...

# %%
data.loc[['India','China','Japan'],:]
# Out:
#                 Region  Happiness Rank  Happiness Score  Standard Error  \
# Country
# India    Southern Asia             117            4.565         0.02043
# China     Eastern Asia              84            5.140         0.02424
# Japan     Eastern Asia              46            5.987         0.03581
#
#          Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# Country
# India                     0.64499  0.38174                   0.51529  0.39786
# China                     0.89012  0.94675                   0.81658  0.51697
# Japan                     1.27074  1.25712                   0.99111  0.49615
#
#          Trust (Government Corruption)  Generosity  Dystopia Residual
# Country
# India                          0.08492     0.26475            2.27513
# China                          0.02781     0.08185            1.86040
# Japan                          0.18060     0.10705            1.68435

# %%
data.loc[['India','China','Japan'],'Happiness Rank']
# Out:
# Country
# India    117
# China     84
# Japan     46
# Name: Happiness Rank, dtype: int64
