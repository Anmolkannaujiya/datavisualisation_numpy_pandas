# %% [markdown]
# ### scaler in numpy (scaler means normal number )

# %%
import numpy as np

# %%
arr = np.array([1,4,6,234,78,43])

# %%
arr *2
# Out:
# array([  2,   8,  12, 468, 156,  86])

# %%
arr ** 2
# Out:
# array([    1,    16,    36, 54756,  6084,  1849])

# %%
arr / 3
# Out:
# array([ 0.33333333,  1.33333333,  2.        , 78.        , 26.        ,
#        14.33333333])

# %%
arr + 34
# Out:
# array([ 35,  38,  40, 268, 112,  77])

# %%
arr -3
# Out:
# array([ -2,   1,   3, 231,  75,  40])

# %%
#works for 2d and 3d as well in the same fashion

# %%
arr = arr.reshape(2,-1)

# %%
arr**2
# Out:
# array([[    1,    16,    36],
#        [54756,  6084,  1849]])

# %%
arr + 69
# Out:
# array([[ 70,  73,  75],
#        [303, 147, 112]])
